# %%
# 서울시 구별 CCTV 데이터와 인구 합치기
import numpy as np
import pandas as pd

# %%
### 1. CCTV 데이터

# %%
cctv = pd.read_csv("서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv",
    skiprows=1, encoding = 'EUC-KR')
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77,032    7,667  2,200  3,491  4,439  6,582  8,129  9,947  9,876
# 1  종로구   1,772      813      0      0    210    150      1    261     85
# 2  중 구   2,333       16    114     87     77    236    240    372    386
# 3  용산구   2,383       34     71    234    125    221    298    351    125
# 4  성동구   3,602      448    125    212    105    339    310    874    390
#
#     2019년   2020년  2021년
# 0  11,961  11,132  1,608
# 1       9     200     43
# 2     155     361    289
# 3     307     617      0
# 4     262     461     76

# %%
#Null data가 있는지 확인
cctv.isna().sum().sum()
# Out:
# 0

# %%
#1000 단위 구분기호 없애기
for column in cctv.columns[1:]:
    cctv[column] =cctv[column].apply(lambda x : int(x.replace(',','')))

cctv.head(3)
# Out:
#     구분     총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77032      7667   2200   3491   4439   6582   8129   9947   9876
# 1  종로구   1772       813      0      0    210    150      1    261     85
# 2  중 구   2333        16    114     87     77    236    240    372    386
#
#    2019년  2020년  2021년
# 0  11961  11132   1608
# 1      9    200     43
# 2    155    361    289

# %%
# 3개년 최근 증가율
cctv['최근3개년'] = cctv['2018년'] + cctv['2019년'] + cctv['2020년']
cctv['2017년 이전'] = cctv. 총계 - cctv['최근3개년'] - cctv['2021년']  # cctv.총계는 컬럼에서는 쓸수 있다
cctv['최근 증가율'] = (cctv['최근3개년'] / cctv['2017년 이전'] * 100).round(2)
cctv.head(3)
# Out:
#     구분     총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77032      7667   2200   3491   4439   6582   8129   9947   9876
# 1  종로구   1772       813      0      0    210    150      1    261     85
# 2  중 구   2333        16    114     87     77    236    240    372    386
#
#    2019년  2020년  2021년  최근3개년  2017년 이전  최근 증가율
# 0  11961  11132   1608  32969     42455   77.66
# 1      9    200     43    294      1435   20.49
# 2    155    361    289    902      1142   78.98

# %%
# cctv. 하면 맨뒤에 최근 3개년, 총계 등을 쓸 수 있다.

# %%
cctv['최근증가율2'] = (cctv.iloc[:,9:12].sum(axis =1) / cctv.iloc[:,2:9].sum(axis =1) *100).round(2)

# %%
cctv.head(3)
# Out:
#     구분     총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  77032      7667   2200   3491   4439   6582   8129   9947   9876
# 1  종로구   1772       813      0      0    210    150      1    261     85
# 2  중 구   2333        16    114     87     77    236    240    372    386
#
#    2019년  2020년  2021년  최근3개년  2017년 이전  최근 증가율  최근증가율2
# 0  11961  11132   1608  32969     42455   77.66   77.66
# 1      9    200     43    294      1435   20.49   20.49
# 2    155    361    289    902      1142   78.98   78.98

# %%
# Selection - 필요한 컬럼 추출
cctv = cctv[['구분','총계', '최근증가율']]
cctv.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-cc0d4c7aa188> in <module>
#       1 # Selection - 필요한 컬럼 추출
# ----> 2 cctv = cctv[['구분','총계', '최근증가율']]
#       3 cctv.head(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['최근증가율'] not in index"

# %%
# 칼럼명 변경
cctv.rename(columns={'구분':'구별', '총계': 'cctv 댓수'}, inplace = True)
cctv.head(3)
# Out:
#     구별  cctv 댓수  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계    77032      7667   2200   3491   4439   6582   8129   9947   9876
# 1  종로구     1772       813      0      0    210    150      1    261     85
# 2  중 구     2333        16    114     87     77    236    240    372    386
#
#    2019년  2020년  2021년  최근3개년  2017년 이전  최근 증가율  최근증가율2
# 0  11961  11132   1608  32969     42455   77.66   77.66
# 1      9    200     43    294      1435   20.49   20.49
# 2    155    361    289    902      1142   78.98   78.98

# %%
# 첫번째 행()
cctv.drop([0], inplace= True)
cctv.head()
# Out:
#     구분    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 1  종로구  1772       813      0      0    210    150      1    261     85
# 2  중 구  2333        16    114     87     77    236    240    372    386
# 3  용산구  2383        34     71    234    125    221    298    351    125
# 4  성동구  3602       448    125    212    105    339    310    874    390
# 5  광진구  2588        35     57    100    187     98     52    675    465
#
#    2019년  2020년  2021년  최근3개년  2017년 이전  최근 증가율  최근증가율2
# 1      9    200     43    294      1435   20.49   20.49
# 2    155    361    289    902      1142   78.98   78.98
# 3    307    617      0   1049      1334   78.64   78.64
# 4    262    461     76   1113      2413   46.13   46.13
# 5    712    175     32   1352      1204  112.29  112.29

# %%
# 구 이름에서 공백지우기
cctv.구별 = cctv.구별.str.replace(' ','')
cctv.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-e75f0b224276> in <module>
#       1 # 구 이름에서 공백지우기
# ----> 2 cctv.구별 = cctv.구별.str.replace(' ','')
#       3 cctv.head(3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute '구별'

# %%
# CCTV 댓수가 많은 자치구 top5
cctv.sort_values('CCTV댓수', ascending = False).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-2155328153e6> in <module>
#       1 # CCTV 댓수가 많은 자치구 top5
# ----> 2 cctv.sort_values('CCTV댓수', ascending = False).head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'CCTV댓수'

# %%
#2. 서울시 인구 데이터

# %%
pop = pd.read_csv("서울시주민등록인구(구별)통계.txt", sep = '\t', skiprows=2)

# %%
pop.isna().sum().sum()
# Out:
# 0

# %%
# 필요한 컬럼 추출 및 이름 변경
pop = pop[['자치구', '계','계.2', '65세이상고령자']]
pop.columns = ['구별', '인구수', '외국인','고령자']
pop.head()
# Out:
#     구별        인구수      외국인        고령자
# 0   합계  9,795,426  229,436  1,576,971
# 1  종로구    155,106    9,077     27,605
# 2   중구    132,259    9,243     23,980
# 3  용산구    240,665   14,287     38,884
# 4  성동구    295,767    6,605     45,591

# %%
# 천단위 구분 기호 없애기
for column in pop.columns[1:]:
    pop[column] = pop[column].str.replace(',','').astype(int)

pop.head(3)
# Out:
#     구별      인구수     외국인      고령자
# 0   합계  9795426  229436  1576971
# 1  종로구   155106    9077    27605
# 2   중구   132259    9243    23980

# %%
# 첫번째 행 지우기
pop.drop([0], inplace = True)

# %%
# 외국인 비율, 고령자비율 칼럼 만들기
pop['외국인비율'] = (pop.외국인 / pop.인구수 *100).round(2)
pop['고령자비율'] = (pop.고령자 / pop.인구수 *100).round(2)
pop.head()
# Out:
#     구별     인구수    외국인    고령자  외국인비율  고령자비율
# 1  종로구  155106   9077  27605   5.85  17.80
# 2   중구  132259   9243  23980   6.99  18.13
# 3  용산구  240665  14287  38884   5.94  16.16
# 4  성동구  295767   6605  45591   2.23  15.41
# 5  광진구  355306  12825  50815   3.61  14.30

# %%
### 3. 두개의 데이터프레임 합치기

# %%
df = pd.merge(cctv, pop)
df.head()
# Out:
#     구별  cctv 댓수  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구     1772       813      0      0    210    150      1    261     85
# 1   중구     2333        16    114     87     77    236    240    372    386
# 2  용산구     2383        34     71    234    125    221    298    351    125
# 3  성동구     3602       448    125    212    105    339    310    874    390
# 4  광진구     2588        35     57    100    187     98     52    675    465
#
#    ...  2021년  최근3개년  2017년 이전  최근 증가율  최근증가율2     인구수    외국인    고령자  외국인비율  \
# 0  ...     43    294      1435   20.49   20.49  155106   9077  27605   5.85
# 1  ...    289    902      1142   78.98   78.98  132259   9243  23980   6.99
# 2  ...      0   1049      1334   78.64   78.64  240665  14287  38884   5.94
# 3  ...     76   1113      2413   46.13   46.13  295767   6605  45591   2.23
# 4  ...     32   1352      1204  112.29  112.29  355306  12825  50815   3.61
#
#    고령자비율
# 0  17.80
# 1  18.13
# 2  16.16
# 3  15.41
# 4  14.30
#
# [5 rows x 22 columns]

# %%
df.set_index('구별', inplace = True)
df.head()
# Out:
#      cctv 댓수  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 구별
# 종로구     1772       813      0      0    210    150      1    261     85
# 중구      2333        16    114     87     77    236    240    372    386
# 용산구     2383        34     71    234    125    221    298    351    125
# 성동구     3602       448    125    212    105    339    310    874    390
# 광진구     2588        35     57    100    187     98     52    675    465
#
#      2019년  ...  2021년  최근3개년  2017년 이전  최근 증가율  최근증가율2     인구수    외국인    고령자  \
# 구별          ...
# 종로구      9  ...     43    294      1435   20.49   20.49  155106   9077  27605
# 중구     155  ...    289    902      1142   78.98   78.98  132259   9243  23980
# 용산구    307  ...      0   1049      1334   78.64   78.64  240665  14287  38884
# 성동구    262  ...     76   1113      2413   46.13   46.13  295767   6605  45591
# 광진구    712  ...     32   1352      1204  112.29  112.29  355306  12825  50815
#
#      외국인비율  고령자비율
# 구별
# 종로구   5.85  17.80
# 중구    6.99  18.13
# 용산구   5.94  16.16
# 성동구   2.23  15.41
# 광진구   3.61  14.30
#
# [5 rows x 21 columns]

# %%
df.to_csv('서울시_CCTV_인구_병합데이터.csv')

# %%
print(1,2,3,4,5,6,7,8,9   sep = ?)  # 앞을 포지셔널 아규먼트 //뒤를 키워드형 아규먼트
# Out:
#   File "<ipython-input-16-b4beacd04276>", line 1
#     print(1,2,3,4,5,6,7,8,9   sep = )  # 앞을 포지셔널 아규먼트 뒤를 키워드형 아규먼트
#                               ^
# SyntaxError: invalid syntax

# %%
 def func(name, age, addr = '양평역'):   # addr는 키워드 인수, 파이썬에서 가변 인수가 허용이 된다.
    print(name, age, addr)

# %%
func('마리아', 25 ,'서울시 영등포구 양평동')
# Out:
# 마리아 25 서울시 영등포구 양평동

# %%
func(name = '마리아', age = 25 )
# Out:
# 마리아 25 양평역

# %%
- 참고사항

# %%
# polymorphisim(다향성) : 자바는 overriding(상속을 받은다음에 부모의 속성값과 메소드를 자식이 그대로 사용할 수 있다.), overloading()
#
from sklearn.base import BaseEstimator

def class Myclassifier(BaseEstimator):
    def fit(self, X, y):
        pass
    def predict(self, X):
        return 0
    def score(self, X, y):
        pass
# Out:
#   File "<ipython-input-27-954395d73856>", line 4
#     def class Myclassifier(BaseEstimator):
#         ^
# SyntaxError: invalid syntax

# %%
def func1(a,b):
    """ 이곳은 함수에 대한 설명을 적는 부분입니다.
    인수 a는 어쩌구, 저쩌구, b는 이렇고 저렇고"""
    pass

# %%
# 키워드 인수가 위치 인수 보다 앞에 위치
func1()

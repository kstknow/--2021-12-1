# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
ans = sns.load_dataset('anscombe')
ans.head(3)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58

# %%
ans.shape
# Out:
# (44, 3)

# %% [markdown]
# - dataset | 에 대해서 그래프를 그려봄

# %%
ds = ans[ans.dataset =='I']
ds
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %% [markdown]
# -회귀식 y = 0.5 * x +3

# %%
plt.scatter(ds.x, ds.y)
plt.plot([4,14],[5,10], 'r-', lw =2)
plt.title('Dataset I')
plt.show()

# %% [markdown]
#  - 4개의 그래프를 하나의 그림에 그리기

# %%
i = 0
for roman in ['I','II','III','IV']:
    ax = axs[i//2, i%2]
    i += 1

    # 이것을 합한것이 enumerate

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,8))
for i,roman in enumerate(['I','II','III','IV']):
    ax = axs[i//2, i%2]
    ds = ans[ans.dataset == roman]
    ax.scatter(ds.x,ds.y)
    ax.plot([3,20],[4.5,13], 'r-', lw =2)
    ax.set_ylim(-2,13)
    ax.set_title(f'Dataset {roman}')

# %%
 # - 최종그림

 fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,8), sharex = True)    # sharex를 해주면 4개의 그래프를 공통적으로 만들어 준다.
for i,roman in enumerate(['I','II','III','IV']):
    ax = axs[i//2, i%2]
    ds = ans[ans.dataset == roman]
    ax.scatter(ds.x,ds.y)
    ax.plot([3,20],[4.5,13], 'r-', lw =2)
    ax.set_ylim(-2,13)
    ax.set_title(f'Dataset {roman}')
plt.suptitle("Anscombe's quartet", fontsize =20)
plt.tight_layout()
plt.show()
